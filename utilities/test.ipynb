# %%
from mcp_discovery import MCPDiscovery

# %%
o=MCPDiscovery("mcp_config.json")
o.list_servers()
# Out:
# {'terminal_server': {'command': 'C:/Users/Prathamesh/prathamesh/ai_agent/ai_agent_env/Scripts/python.exe',
#   'args': ['C:/Users/Prathamesh/prathamesh/ai_agent/mcp_a2a_multiagent/servers/streamable_http_server.py']},
#  'arithematic_server': {'command': 'streamable_http',
#   'args': ['http://localhost:3000/mcp/']}}

# %%
import json

data = {"name": "Alice", "age": 30, "city": "New York"}

# Convert to a basic JSON string
json_string1 = json.dumps(data) 
json_string2 = json.dumps(data) 

o= "".join([json_string1,json_string2])
# Convert to a "pretty-printed" JSON string
pretty_json = json.dumps(data, indent=4, sort_keys=True)
print(o)
# Out:
# {"name": "Alice", "age": 30, "city": "New York"}{"name": "Alice", "age": 30, "city": "New York"}

# %%
text="""
sdfvvvcvbxxxxx

dknlgkdmbkldibgkobmetjhkjoijfsporjk09krwop
"""

s=0
end=0

last_break = text.rfind("\n\n")
if last_break > 30:
    end = s + last_break

print(text[s:end])
